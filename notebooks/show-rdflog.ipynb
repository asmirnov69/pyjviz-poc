# %%
import sys; sys.path.append("..")
import graphviz 
from IPython.display import display
import rdflib
import janitor.pyjviz as pyjviz

pyjlog_ttl_fn = "./rdflog.ttl"
g = rdflib.Graph()
g.parse(pyjlog_ttl_fn)
dot_code = pyjviz.dump_dot_code(g)

source= dot_code
gvz=graphviz.Source(source)
# produce PDF
#gvz.view()
#print (gvz.source)
display(gvz)
